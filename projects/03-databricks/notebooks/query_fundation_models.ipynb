# %%
import sys
# !uv pip install --python {sys.executable} openai python-dotenv

# %%
from dotenv import load_dotenv
from openai import OpenAI
import os

load_dotenv()

host = os.environ["DATABRICKS_HOST"].rstrip("/")
token = os.environ["DATABRICKS_TOKEN"]
endpoint = os.environ.get("DATABRICKS_MODEL_ENDPOINT")

if not endpoint:
    raise ValueError(
        "Set DATABRICKS_MODEL_ENDPOINT in your .env to your Databricks serving endpoint name."
    )

client = OpenAI(
    api_key=token,
    base_url=f"{host}/serving-endpoints",
)

response = client.chat.completions.create(
    model=endpoint,
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Explain Delta Lake in one paragraph."},
    ],
    max_tokens=256,
)

print(response.choices[0].message.content)
