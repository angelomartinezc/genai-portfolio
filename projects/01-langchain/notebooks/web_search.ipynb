# %% [markdown]
# # Web Seach

# %%
from pprint import pprint
from dotenv import load_dotenv
load_dotenv()

from langchain.agents import create_agent
from langchain.messages import HumanMessage
from langchain.tools import tool

from typing import Dict, Any
from tavily import TavilyClient

# %%
tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:
    """Search the web for information"""
    return tavily_client.search(query=query)

# %%
MODEL_NAME = "openai:gpt-5-nano"

agent = create_agent(
    model=MODEL_NAME, 
    tools=[web_search]
)

# %%
question = HumanMessage(content="I would to know the top news for Ecuador for yesterday 28 February 2026")

response = agent.invoke(
    {"messages": [question]}
)

pprint(response["messages"][-1].content)
# Out:
# ('Here are the top Ecuador-related news items I found for yesterday, 28 '
#  'February 2026:\n'
#  '\n'
#  '- Earthquake near Quito\n'
#  '  - A magnitude 3.5 earthquake struck in the evening near Quito, Province of '
#  'Pichincha, Ecuador, at about 8:57 pm local time. No major damage or '
#  'casualties were immediately reported, but authorities were monitoring the '
#  'situation. Source: Volcanodiscovery (quake reports).\n'
#  '\n'
#  '- Ecuador to raise tariffs on Colombian imports to 50% starting March 1\n'
#  '  - The government announced an increase in tariffs on Colombian imports '
#  'from 30% to 50%, effective March 1, as part of an ongoing border-security '
#  'and trade dispute with Colombia. This follows earlier moves to impose a 30% '
#  'tariff and escalates a broader bilateral row over security and drug '
#  'trafficking along the border. Sources include Reuters and AP coverage from '
#  'Feb 26–27, 2026, noting the March 1 date.\n'
#  '\n'
#  '- Continued rhetoric on the Colombia trade dispute\n'
#  '  - President Daniel Noboa publicly characterized Colombia as Ecuador’s '
#  'worst trading partner in terms of tariff-adjusted costs, as part of the '
#  'evolving trade confrontation. This theme was reported by AP News and '
#  'mirrored by Reuters coverage around Feb 26–27, 2026.\n'
#  '\n'
#  '- Diplomatic visit noted\n'
#  '  - Reports indicated invitations and planning for high-level diplomatic '
#  'engagement, including an official visit by a regional leader (Sheikh Khaled) '
#  'to Ecuador as part of strengthening ties and cooperation in the region. '
#  'Source: AP News (late Feb 2026).\n'
#  '\n'
#  '- Security/press freedom context (brief note)\n'
#  '  - There were reports from observers about threats to journalists in '
#  'Ecuador during Jan–Feb 2026, highlighting concerns about safety and '
#  'protection for media and the authorities’ response. Source: RSF (Reporters '
#  'Without Borders) coverage.\n'
#  '\n'
#  'Would you like me to pull in the full articles or provide a concise timeline '
#  'and more details on any of these items (e.g., the exact tariff lists, '
#  'earthquake aftershocks, or the content of the diplomatic visit)?')
