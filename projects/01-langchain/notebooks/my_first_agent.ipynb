# %% [markdown]
# # My first Agent

# %%
from langchain.agents import create_agent
from pprint import pprint
from tavily import TavilyClient
from typing import Dict, Any
from langchain.tools import tool
from langchain.messages import HumanMessage

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Define the tool (agent's hands)

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:
    """Seach web for informatiom"""
    
    return (
        tavily_client.search(
            query,
            search_depth='advanced',
            max_results=3,
            include_answer=True
        )
    )

# %%
# Initialize the model (agent's brain)

MODEL_NAME = "openai:gpt-5-nano"

agent = create_agent(
    model=MODEL_NAME,
    tools=[web_search],
)

# %%
response = agent.invoke(
    input={"messages": [HumanMessage(content="Did Emelec win yesterday?")]}
)

# %%
pprint(response['messages'][-1].content)
# Out:
# ('No. Yesterday’s match (Feb 28, 2026) against Delfín SC ended in a 1-1 draw '
#  'in Liga Pro. Emelec were the home team at Estadio Banco del Pacífico Capwell '
#  'and earned 1 point from the game. Want a quick recap or the full match '
#  'report/highlights?')
